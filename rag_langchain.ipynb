# %%
pip install -r requirements.txt
# Out:
# Ignoring pysqlite3-binary: markers 'sys_platform == "linux"' don't match your environment
# Requirement already satisfied: ipykernel in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (6.29.5)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (1.0.1)
# Collecting aiohappyeyeballs==2.4.0 (from -r requirements.txt (line 4))
#   Using cached aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiohttp==3.10.5 (from -r requirements.txt (line 5))
#   Using cached aiohttp-3.10.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (7.5 kB)
# Collecting aiosignal==1.3.1 (from -r requirements.txt (line 6))
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting altair==5.4.1 (from -r requirements.txt (line 7))
#   Using cached altair-5.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: annotated-types==0.7.0 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 8)) (0.7.0)
# Collecting anthropic==0.34.2 (from -r requirements.txt (line 9))
#   Using cached anthropic-0.34.2-py3-none-any.whl.metadata (18 kB)
# Collecting anyio==4.5.0 (from -r requirements.txt (line 10))
#   Using cached anyio-4.5.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: asgiref==3.8.1 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 11)) (3.8.1)
# Collecting asttokens==2.4.1 (from -r requirements.txt (line 12))
#   Using cached asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting attrs==24.2.0 (from -r requirements.txt (line 13))
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: backoff==2.2.1 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 14)) (2.2.1)
# Collecting bcrypt==4.2.0 (from -r requirements.txt (line 15))
#   Using cached bcrypt-4.2.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (9.6 kB)
# Collecting beautifulsoup4==4.12.3 (from -r requirements.txt (line 16))
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting blinker==1.8.2 (from -r requirements.txt (line 17))
#   Using cached blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: bs4==0.0.2 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 18)) (0.0.2)
# Collecting build==1.2.2 (from -r requirements.txt (line 19))
#   Using cached build-1.2.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting cachetools==5.5.0 (from -r requirements.txt (line 20))
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting certifi==2024.8.30 (from -r requirements.txt (line 21))
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer==3.3.2 (from -r requirements.txt (line 22))
#   Using cached charset_normalizer-3.3.2-py3-none-any.whl.metadata (33 kB)
# Collecting chroma-hnswlib==0.7.3 (from -r requirements.txt (line 23))
#   Using cached chroma_hnswlib-0.7.3-cp313-cp313-macosx_10_13_universal2.whl
# Collecting chromadb==0.5.3 (from -r requirements.txt (line 24))
#   Using cached chromadb-0.5.3-py3-none-any.whl.metadata (6.8 kB)
# Collecting click==8.1.7 (from -r requirements.txt (line 25))
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting colorama==0.4.6 (from -r requirements.txt (line 26))
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: coloredlogs==15.0.1 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 27)) (15.0.1)
# Requirement already satisfied: comm==0.2.2 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 28)) (0.2.2)
# Requirement already satisfied: dataclasses-json==0.6.7 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 29)) (0.6.7)
# Collecting debugpy==1.8.5 (from -r requirements.txt (line 30))
#   Using cached debugpy-1.8.5-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from -r requirements.txt (line 31))
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting defusedxml==0.7.1 (from -r requirements.txt (line 32))
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting Deprecated==1.2.14 (from -r requirements.txt (line 33))
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: distro==1.9.0 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 34)) (1.9.0)
# Requirement already satisfied: docx2txt==0.8 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 35)) (0.8)
# Collecting executing==2.1.0 (from -r requirements.txt (line 36))
#   Using cached executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting fastapi==0.115.0 (from -r requirements.txt (line 37))
#   Using cached fastapi-0.115.0-py3-none-any.whl.metadata (27 kB)
# Collecting filelock==3.16.1 (from -r requirements.txt (line 38))
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting flatbuffers==24.3.25 (from -r requirements.txt (line 39))
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting frozenlist==1.4.1 (from -r requirements.txt (line 40))
#   Using cached frozenlist-1.4.1-py3-none-any.whl.metadata (12 kB)
# Collecting fsspec==2024.9.0 (from -r requirements.txt (line 41))
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting gitdb==4.0.11 (from -r requirements.txt (line 42))
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting GitPython==3.1.43 (from -r requirements.txt (line 43))
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting google-auth==2.34.0 (from -r requirements.txt (line 44))
#   Using cached google_auth-2.34.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting googleapis-common-protos==1.65.0 (from -r requirements.txt (line 45))
#   Using cached googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting greenlet==3.1.0 (from -r requirements.txt (line 46))
#   Using cached greenlet-3.1.0-cp313-cp313-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting grpcio==1.66.1 (from -r requirements.txt (line 47))
#   Using cached grpcio-1.66.1.tar.gz (12.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: h11==0.14.0 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 48)) (0.14.0)
# Collecting httpcore==1.0.5 (from -r requirements.txt (line 49))
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting httptools==0.6.1 (from -r requirements.txt (line 50))
#   Using cached httptools-0.6.1.tar.gz (191 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting httpx==0.27.2 (from -r requirements.txt (line 51))
#   Using cached httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting huggingface-hub==0.25.0 (from -r requirements.txt (line 52))
#   Using cached huggingface_hub-0.25.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: humanfriendly==10.0 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 53)) (10.0)
# Requirement already satisfied: idna==3.10 in ./.venv/lib/python3.13/site-packages (from -r requirements.txt (line 54)) (3.10)
# Collecting importlib_metadata==8.4.0 (from -r requirements.txt (line 55))
#   Using cached importlib_metadata-8.4.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting importlib_resources==6.4.5 (from -r requirements.txt (line 56))
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting ipython==8.27.0 (from -r requirements.txt (line 58))
#   Using cached ipython-8.27.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting jedi==0.19.1 (from -r requirements.txt (line 59))
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting Jinja2==3.1.4 (from -r requirements.txt (line 60))
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jiter==0.5.0 (from -r requirements.txt (line 61))
#   Using cached jiter-0.5.0.tar.gz (158 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Checking for Rust toolchain....
#
#       Cargo, the Rust package manager, is not installed or is not on PATH.
#       This package requires Rust and Cargo to compile extensions. Install it through
#       the system's package manager or via https://rustup.rs/
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import dotenv
from pathlib import Path
from dotenv import load_dotenv  # new addition

from langchain_core.messages import AIMessage, HumanMessage
from langchain_community.document_loaders.text import TextLoader
from langchain_community.document_loaders import (
    WebBaseLoader, 
    PyPDFLoader, 
    Docx2txtLoader,
)
from langchain_community.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_anthropic import ChatAnthropic
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.chains import create_history_aware_retriever, create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

dotenv.load_dotenv()
# Out:
# True

# %%
# Load docs

doc_paths = [
    "docs/test_rag.pdf",
    "docs/test_rag.docx",
]

docs = [] 
for doc_file in doc_paths:
    file_path = Path(doc_file)

    try:
        if doc_file.endswith(".pdf"):
            loader = PyPDFLoader(file_path)
        elif doc_file.endswith(".docx"):
            loader = Docx2txtLoader(file_path)
        elif doc_file.endswith(".txt") or doc_file.name.endswith(".md"):
            loader = TextLoader(file_path)
        else:
            print(f"Document type {doc_file.type} not supported.")
            continue

        docs.extend(loader.load())

    except Exception as e:
        print(f"Error loading document {doc_file.name}: {e}")


# Load URLs

url = "https://docs.streamlit.io/develop/quick-reference/release-notes"
try:
    loader = WebBaseLoader(url)
    docs.extend(loader.load())

except Exception as e:
    print(f"Error loading document from {url}: {e}")

# %%
docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2024-09-15T19:40:36+02:00', 'msip_label_1cf2ba15-c468-47c8-b178-cba8acf110ec_siteid': 'eb25818e-5bd5-49bf-99de-53e3e7b42630', 'msip_label_1cf2ba15-c468-47c8-b178-cba8acf110ec_method': 'Standard', 'msip_label_1cf2ba15-c468-47c8-b178-cba8acf110ec_enabled': 'True', 'author': 'Domingo Domènech Enric (ERNI)', 'moddate': '2024-09-15T19:40:36+02:00', 'source': 'docs/test_rag.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='My favorite food is margarita pizza. \nThere are 47588 bottles in the truck.'),
#  Document(metadata={'source': 'docs/test_rag.docx'}, page_content='My favorite food is margarita pizza.\n\nThere are 47588 bottles in the truck.'),
#  Document(metadata={'source': 'https://docs.streamlit.io/develop/quick-reference/release-notes', 'title': 'Release notes - Streamlit Docs', 'description': 'A changelog of highlights and fixes for each version of Streamlit.', 'language': 'No language found.'}, page_content='Release notes - Streamlit DocsDocumentationsearchSearchrocket_launchGet startedInstallationaddFundamentalsaddFirst stepsaddcodeDevelopConceptsaddAPI referenceaddTutorialsaddQuick referenceremoveCheat sheetRelease notesremove2025202420232022202120202019Pre-release featuresRoadmapopen_in_newweb_assetDeployConceptsaddStreamlit Community CloudaddSnowflakeOther platformsaddschoolKnowledge baseFAQInstalling dependenciesDeployment issuesHome/Develop/Quick reference/Release notesRelease notes\nThis page lists highlights, bug fixes, and known issues for the latest release of Streamlit. If you\'re looking for information about nightly releases or experimental features, see Pre-release features.\nUpgrade Streamlit\nstarTipTo upgrade to the latest version of Streamlit, run:pip install --upgrade streamlit\n\nVersion 1.43.0 (latest)\nRelease date: March 4, 2025\nHighlights\n\n\uf8ffüìÅ¬†Announcing the option to accept files with st.chat_input!\n\uf8ffüìí Introducing a new column type for column configuration! Use JsonColumn to show JSON-compatible objects.\n\nNotable Changes\n\n\uf8ffüèÉ¬†You can prevent st.download_button from triggering a rerun by setting on_click="ignore" (#10296, #4382).\n\uf8ffüïë¬†You can access a user\'s timezone and timezone offset through st.context (#10336).\n‚ÜïÔ∏è¬†You can configure the row height in st.dataframe and st.data_editor with a new parameter (#9549, #7266, #8632, #5386).\n\uf8ffüíÖ¬†st.dataframe and st.data_editor use use_container_width=True by default (#10434).\n\uf8ffü§è¬†Markdown has a small text directive (#10487, #10486).\n\uf8ffüßµ¬†You can pass strings, paths, and callables to st.navigation in place of StreamlitPage objects for convenience (#10358, #10069). Thanks, ashm-dev!\n\uf8ffüìà¬†Streamlit has a new custom component, streamlit-bokeh, to support the latest version of Bokeh (#10374, #5858).\n\uf8ffüî£¬†NumberColumn, ProgressColumn, DatetimeColumn, DateColumn, and TimeColumn have preconfigured format options for ease of use (#10179, #8788, #7702).\n\uf8ffüõéÔ∏è¬†Static file serving supports files with JSON, XML, and common font file extensions. (#10417,¬†#10335,¬†#10337,¬†#10302).\n\nOther Changes\n\n\uf8ffü•∑¬†Users can hide dataframe columns (#10264, #6870).\n\uf8ffüìÖ¬†Users can change the format of numbers, dates, and times in dataframes (#10420).\n‚ÜîÔ∏è¬†Users can auto-size column widths (#10476).\n\uf8ffüêª‚Äç‚ùÑÔ∏è¬†Streamlit supports Polars dataframe and series hashing (#10408, #10347).\n‚ò†Ô∏è¬†rich is no longer a required dependency for Streamlit (#10320).\n\uf8ffü¶ã¬†st.file_uploader has a better display format in narrow containers (#10272).\n\uf8ffü¶é¬†Bug fix: Tabs are prevented from having a width of zero to prevent flickering (#10533).\n\uf8ffüêå¬†Bug fix: Column order is correctly displayed when set in column configuration (#10445, #10442).\n\uf8ffüï∏Ô∏è¬†Bug fix: We updated dataframe null handling to prevent deprecation warnings (#10484).\n\uf8ffü¶ó¬†Bug fix: Elapsed time doesn\'t overflow for st.audio_input (#10410, #10373). Thanks, ashm-dev!\n\uf8ffü¶Ç¬†Bug fix: st.altair_chart does not show an incorrect "true" tooltip when the user makes a selection (#10456, #10448).\n\uf8ffü¶ü¬†Bug fix: Streamlit does not raise a RuntimeError when an asyncio event loop is not already running (#10455, #10452).\n\uf8ffü¶†¬†Bug fix: The key for an internal MIME type is set correctly to avoid a browser warning (#10404).\n\uf8ffü™∞¬†Bug fix: st.data_editor automatically scrolls to the bottom when a user adds a row (#10405, #10351).\n\uf8ffü™≥¬†Bug fix: Tooltips are suppressed on user-added rows in st.data_editor to prevent erroneous warnings (#10398).\n\uf8ffüï∑Ô∏è¬†Bug fix: st.logo displays consistently when used with f ...

# %%
# Split docs

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=5000,
    chunk_overlap=1000,
)

document_chunks = text_splitter.split_documents(docs)

# %%
# Tokenize and load the documents to the vector store

vector_db = Chroma.from_documents(
    documents=document_chunks,
    embedding=OpenAIEmbeddings(),
)

# %%
# Retrieve

def _get_context_retriever_chain(vector_db, llm):
    retriever = vector_db.as_retriever()
    prompt = ChatPromptTemplate.from_messages([
        MessagesPlaceholder(variable_name="messages"),
        ("user", "{input}"),
        ("user", "Given the above conversation, generate a search query to look up in order to get inforamtion relevant to the conversation, focusing on the most recent messages."),
    ])
    retriever_chain = create_history_aware_retriever(llm, retriever, prompt)

    return retriever_chain

# %%
def get_conversational_rag_chain(llm):
    retriever_chain = _get_context_retriever_chain(vector_db, llm)

    prompt = ChatPromptTemplate.from_messages([
        ("system",
        """You are a helpful assistant. You will have to answer to user's queries.
        You will have some context to help with your answers, but now always would be completely related or helpful.
        You can also use your knowledge to assist answering the user's queries.\n
        {context}"""),
        MessagesPlaceholder(variable_name="messages"),
        ("user", "{input}"),
    ])
    stuff_documents_chain = create_stuff_documents_chain(llm, prompt)

    return create_retrieval_chain(retriever_chain, stuff_documents_chain)

# %%
# Augmented Generation

llm_stream_openai = ChatOpenAI(
    model="gpt-4o",  # Here you could use "o1-preview" or "o1-mini" if you already have access to them
    temperature=0.3,
    streaming=True,
)

llm_stream_anthropic = ChatAnthropic(
    model="claude-3-5-sonnet-20240620",
    temperature=0.3,
    streaming=True,
)

llm_stream = llm_stream_openai  # Select between OpenAI and Anthropic models for the response

messages = [
    {"role": "user", "content": "Hi"},
    {"role": "assistant", "content": "Hi there! How can I assist you today?"},
    {"role": "user", "content": "What is the latest version of Streamlit?"},
]
messages = [HumanMessage(content=m["content"]) if m["role"] == "user" else AIMessage(content=m["content"]) for m in messages]

conversation_rag_chain = get_conversational_rag_chain(llm_stream)
response_message = "*(RAG Response)*\n"
for chunk in conversation_rag_chain.pick("answer").stream({"messages": messages[:-1], "input": messages[-1].content}):
    response_message += chunk
    print(chunk, end="", flush=True)

messages.append({"role": "assistant", "content": response_message})
# Out:
# Number of requested results 4 is greater than number of elements in index 3, updating n_results = 3
# The latest version of Streamlit is 1.43.0, released on March 4, 2025.

# %%
import os
from langchain_openai import AzureChatOpenAI
import dotenv

dotenv.load_dotenv()

llm_stream = AzureChatOpenAI(
    azure_endpoint=os.getenv("AZ_OPENAI_ENDPOINT"),
    openai_api_version="2024-02-15-preview",
    model_name="gpt-4o",
    openai_api_key=os.getenv("AZ_OPENAI_API_KEY"),
    openai_api_type="azure",
    temperature=0.3,
    streaming=True,
)

prompt = "Tell me something about Azure"

for chunk in llm_stream.stream(prompt):
    print(chunk.content, end="", flush=True)
# Out:
# Certainly! Microsoft Azure is a comprehensive cloud computing platform developed by Microsoft. It provides a wide range of services and tools that enable businesses, developers, and organizations to build, deploy, and manage applications and services through Microsoft-managed data centers. Azure is one of the leading cloud service providers globally, competing with platforms like Amazon Web Services (AWS) and Google Cloud Platform (GCP).
#
# ### Key Features of Azure:
# 1. **Wide Range of Services**: Azure offers over 200 services, including computing, storage, networking, databases, artificial intelligence (AI), machine learning (ML), Internet of Things (IoT), analytics, DevOps, and more.
#
# 2. **Scalability**: Azure allows users to scale resources up or down based on demand, ensuring cost efficiency and performance optimization.
#
# 3. **Global Reach**: Azure has data centers located in regions across the globe, enabling users to deploy applications closer to their customers for better performance and compliance with local regulations.
#
# 4. **Hybrid Cloud Support**: Azure supports hybrid cloud environments, allowing businesses to integrate their on-premises infrastructure with cloud services seamlessly.
#
# 5. **Security and Compliance**: Azure provides robust security features, including encryption, identity management, and threat detection. It also complies with various industry standards and regulations, such as GDPR, HIPAA, and ISO certifications.
#
# 6. **Integration with Microsoft Tools**: Azure integrates well with Microsoft products like Windows Server, Active Directory, SQL Server, and Office 365, making it a popular choice for businesses already using Microsoft technologies.
#
# 7. **Open Source Friendly**: Azure supports a wide range of programming languages, frameworks, and tools, including open-source technologies like Linux, Python, Java, Kubernetes, and Docker.
#
# 8. **Pay-as-You-Go Pricing**: Azure operates on a pay-as-you-go model, meaning users only pay for the resources they use, which helps control costs.
#
# ### Popular Azure Services:
# 1. **Azure Virtual Machines**: Provides scalable, on-demand computing resources.
# 2. **Azure App Service**: Enables developers to build and host web apps, mobile apps, and APIs.
# 3. **Azure Blob Storage**: Offers scalable object storage for unstructured data like images, videos, and backups.
# 4. **Azure SQL Database**: A fully managed relational database service.
# 5. **Azure Kubernetes Service (AKS)**: Simplifies the deployment and management of containerized applications using Kubernetes.
# 6. **Azure Functions**: A serverless computing service for running event-driven code.
# 7. **Azure AI and Machine Learning**: Tools for building, training, and deploying AI models.
# 8. **Azure DevOps**: Provides development tools for CI/CD pipelines, project management, and collaboration.
#
# ### Use Cases for Azure:
# - Hosting websites and applications.
# - Running virtual machines and containers.
# - Data storage and backup solutions.
# - Building AI-powered applications.
# - Analyzing large datasets with big data tools.
# - IoT device management and data processing.
# - Disaster recovery and business continuity.
#
# ### Why Choose Azure?
# - **Flexibility**: Azure supports a wide variety of programming languages, frameworks, and operating systems.
# - **Cost Efficiency**: The pay-as-you-go model and reserved instances help optimize costs.
# - **Enterprise-Grade Solutions**: Azure is tailored for businesses of all sizes, from startups to large enterprises.
# - **Continuous Innovation**: Microsoft regularly updates Azure with new features and services.
#
# Azure is a powerful platform for organizations looking to leverage the benefits of cloud computing, whether for hosting applications, storing data, or building advanced solutions using AI and machine learning.
